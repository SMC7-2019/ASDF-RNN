# %%
#Importing the required 
import os 
os.environ['CUDA_VISIBLE_DEVICES']='1'

import collections
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import librosa
import librosa.display
import IPython.display as ipd
import scipy
import tensorflow as tf
import pandas as pd
import mdn

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, Activation, LSTM, Dropout, Flatten
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks.callbacks import ModelCheckpoint, CSVLogger
from keras.preprocessing import image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale, minmax_scale
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
#Data stored in "SMC_Dataset1/classical" and "SMC_Dataset1/json"
PATH = os.getcwd()

SpectrogramPath = PATH+'/SMC_dataset1/Spectrograms1024.csv'
MotionPath = PATH+'/SMC_dataset1/motion_features9x5.csv'

#Load Motion features
MotionFeat = pd.read_csv(MotionPath, sep=',')
MotionFeat = np.array(MotionFeat).reshape(1201, 9, 5)

#Load Motion features
Spectro = pd.read_csv(SpectrogramPath, sep=',' ,header=None)
print(Spectro.shape)
# Out:
# (1201, 1024)

# %%
#Feature Scaling/Normalisation of Data 

for i in range(1201):
    MotionFeat[i] = minmax_scale(MotionFeat[i],  feature_range=(0, 1), axis=0, copy=False)    

#Select 20% of data for validation set
train_x, validate_x, train_y, validate_y = train_test_split(MotionFeat, Spectro, test_size=0.2, random_state=1)

# %%
#Parameters
batch_size=8
N_MIXES = 10  # number of mixture components
OUTPUT_DIMS = 1024  # number of real-values predicted by each mixture component
# Out:
# output shape: 10260

# %%
# checkpoint
model = load_model('MDN/Model.hdf5', custom_objects={'MDN': mdn.MDN, 'mdn_loss_func': mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES)})

csv_logger = CSVLogger('log.csv', append=True, separator=',')
filepath="MDN/Model3000.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint
                  , csv_logger]

history = model.fit(train_x, train_y, batch_size=batch_size, epochs=1500, validation_data=(validate_x, validate_y), callbacks=callbacks_list, verbose=0)
# Out:
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method MDN.call of <mdn.MDN object at 0x7f813c17bba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MDN.call of <mdn.MDN object at 0x7f813c17bba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method MDN.call of <mdn.MDN object at 0x7f813c17bba8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MDN.call of <mdn.MDN object at 0x7f813c17bba8>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow_probability/python/distributions/mixture.py:154: Categorical.event_size (from tensorflow_probability.python.distributions.categorical) is deprecated and will be removed after 2019-05-19.
# Instructions for updating:
# The `event_size` property is deprecated.  Use `num_categories` instead.  They have the same value, but `event_size` is misnamed.
# WARNING:tensorflow:From /home/dwoodw19/miniconda3/envs/ML_ENV/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:2403: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: val_loss improved from inf to -970.64109, saving model to MDN/Model3000.hdf5
#
# Epoch 00002: val_loss did not improve from -970.64109
#
# Epoch 00003: val_loss improved from -970.64109 to -980.01765, saving model to MDN/Model3000.hdf5
#
# Epoch 00004: val_loss improved from -980.01765 to -984.62273, saving model to MDN/Model3000.hdf5
#
# Epoch 00005: val_loss did not improve from -984.62273
#
# Epoch 00006: val_loss improved from -984.62273 to -991.05548, saving model to MDN/Model3000.hdf5
#
# Epoch 00007: val_loss did not improve from -991.05548
#
# Epoch 00008: val_loss improved from -991.05548 to -1014.72043, saving model to MDN/Model3000.hdf5
#
# Epoch 00009: val_loss improved from -1014.72043 to -1042.33223, saving model to MDN/Model3000.hdf5
#
# Epoch 00010: val_loss did not improve from -1042.33223
#
# Epoch 00011: val_loss did not improve from -1042.33223
#
# Epoch 00012: val_loss did not improve from -1042.33223
#
# Epoch 00013: val_loss did not improve from -1042.33223
#
# Epoch 00014: val_loss did not improve from -1042.33223
#
# Epoch 00015: val_loss did not improve from -1042.33223
#
# Epoch 00016: val_loss did not improve from -1042.33223
#
# Epoch 00017: val_loss improved from -1042.33223 to -1045.52192, saving model to MDN/Model3000.hdf5
#
# Epoch 00018: val_loss did not improve from -1045.52192
#
# Epoch 00019: val_loss did not improve from -1045.52192
#
# Epoch 00020: val_loss did not improve from -1045.52192
#
# Epoch 00021: val_loss did not improve from -1045.52192
#
# Epoch 00022: val_loss did not improve from -1045.52192
#
# Epoch 00023: val_loss did not improve from -1045.52192
#
# Epoch 00024: val_loss did not improve from -1045.52192
#
# Epoch 00025: val_loss did not improve from -1045.52192
#
# Epoch 00026: val_loss did not improve from -1045.52192
#
# Epoch 00027: val_loss did not improve from -1045.52192
#
# Epoch 00028: val_loss did not improve from -1045.52192
#
# Epoch 00029: val_loss did not improve from -1045.52192
#
# Epoch 00030: val_loss did not improve from -1045.52192
#
# Epoch 00031: val_loss did not improve from -1045.52192
#
# Epoch 00032: val_loss did not improve from -1045.52192
#
# Epoch 00033: val_loss did not improve from -1045.52192
#
# Epoch 00034: val_loss did not improve from -1045.52192
#
# Epoch 00035: val_loss did not improve from -1045.52192
#
# Epoch 00036: val_loss did not improve from -1045.52192
#
# Epoch 00037: val_loss did not improve from -1045.52192
#
# Epoch 00038: val_loss did not improve from -1045.52192
#
# Epoch 00039: val_loss did not improve from -1045.52192
#
# Epoch 00040: val_loss did not improve from -1045.52192
#
# Epoch 00041: val_loss did not improve from -1045.52192
#
# Epoch 00042: val_loss did not improve from -1045.52192
#
# Epoch 00043: val_loss did not improve from -1045.52192
#
# Epoch 00044: val_loss did not improve from -1045.52192
#
# Epoch 00045: val_loss did not improve from -1045.52192
#
# Epoch 00046: val_loss did not improve from -1045.52192
#
# Epoch 00047: val_loss did not improve from -1045.52192
#
# Epoch 00048: val_loss did not improve from -1045.52192
#
# Epoch 00049: val_loss did not improve from -1045.52192
#
# Epoch 00050: val_loss did not improve from -1045.52192
#
# Epoch 00051: val_loss did not improve from -1045.52192
#
# Epoch 00052: val_loss did not improve from -1045.52192
#
# Epoch 00053: val_loss did not improve from -1045.52192
#
# Epoch 00054: val_loss did not improve from -1045.52192
#
# Epoch 00055: val_loss did not improve from -1045.52192
#
# Epoch 00056: val_loss did not improve from -1045.52192
#
# Epoch 00057: val_loss did not improve from -1045.52192
#
# Epoch 00058: val_loss did not improve from -1045.52192
#
# Epoch 00059: val_loss did not improve from -1045.52192
#
# Epoch 00060: val_loss did not improve from -1045.52192
#
# Epoch 00061: val_loss did not improve from -1045.52192
#
# Epoch 00062: val_loss did not improve from -1045.52192
#
# Epoch 00063: val_loss did not improve from -1045.52192
#
# Epoch 00064: val_loss did not improve from -1045.52192
#
# Epoch 00065: val_loss did not improve from -1045.52192
#
# Epoch 00066: val_loss did not improve from -1045.52192
#
# Epoch 00067: val_loss did not improve from -1045.52192
#
# Epoch 00068: val_loss did not improve from -1045.52192
#
# Epoch 00069: val_loss did not improve from -1045.52192
#
# Epoch 00070: val_loss did not improve from -1045.52192
#
# Epoch 00071: val_loss did not improve from -1045.52192
#
# Epoch 00072: val_loss did not improve from -1045.52192
#
# Epoch 00073: val_loss did not improve from -1045.52192
#
# Epoch 00074: val_loss did not improve from -1045.52192
#
# Epoch 00075: val_loss did not improve from -1045.52192
#
# Epoch 00076: val_loss did not improve from -1045.52192
#
# Epoch 00077: val_loss did not improve from -1045.52192
#
# Epoch 00078: val_loss did not improve from -1045.52192
#
# Epoch 00079: val_loss did not improve from -1045.52192
#
# Epoch 00080: val_loss did not improve from -1045.52192
#
# Epoch 00081: val_loss did not improve from -1045.52192
#
# Epoch 00082: val_loss did not improve from -1045.52192
#
# Epoch 00083: val_loss did not improve from -1045.52192
#
# Epoch 00084: val_loss did not improve from -1045.52192
#
# Epoch 00085: val_loss did not improve from -1045.52192
# Epoch 00086: val_loss did not improve from -1045.52192
#
# Epoch 00087: val_loss did not improve from -1045.52192
#
# Epoch 00088: val_loss did not improve from -1045.52192
#
# Epoch 00089: val_loss did not improve from -1045.52192
#
# Epoch 00090: val_loss did not improve from -1045.52192
#
# Epoch 00091: val_loss did not improve from -1045.52192
#
# Epoch 00092: val_loss did not improve from -1045.52192
#
# Epoch 00093: val_loss did not improve from -1045.52192
#
# Epoch 00094: val_loss did not improve from -1045.52192
#
# Epoch 00095: val_loss did not improve from -1045.52192
#
# Epoch 00096: val_loss did not improve from -1045.52192
#
# Epoch 00097: val_loss did not improve from -1045.52192
#
# Epoch 00098: val_loss did not improve from -1045.52192
#
# Epoch 00099: val_loss did not improve from -1045.52192
#
# Epoch 00100: val_loss did not improve from -1045.52192
#
# Epoch 00101: val_loss did not improve from -1045.52192
#
# Epoch 00102: val_loss did not improve from -1045.52192
#
# Epoch 00103: val_loss did not improve from -1045.52192
#
# Epoch 00104: val_loss did not improve from -1045.52192
#
# Epoch 00105: val_loss did not improve from -1045.52192
#
# Epoch 00106: val_loss did not improve from -1045.52192
#
# Epoch 00107: val_loss did not improve from -1045.52192
#
# Epoch 00108: val_loss did not improve from -1045.52192
#
# Epoch 00109: val_loss did not improve from -1045.52192
#
# Epoch 00110: val_loss did not improve from -1045.52192
#
# Epoch 00111: val_loss did not improve from -1045.52192
#
# Epoch 00112: val_loss improved from -1045.52192 to -1049.96366, saving model to MDN/Model3000.hdf5
#
# Epoch 00113: val_loss did not improve from -1049.96366
#
# Epoch 00114: val_loss did not improve from -1049.96366
#
# Epoch 00115: val_loss did not improve from -1049.96366
#
# Epoch 00116: val_loss did not improve from -1049.96366
#
# Epoch 00117: val_loss did not improve from -1049.96366
#
# Epoch 00118: val_loss did not improve from -1049.96366
#
# Epoch 00119: val_loss did not improve from -1049.96366
#
# Epoch 00120: val_loss did not improve from -1049.96366
#
# Epoch 00121: val_loss did not improve from -1049.96366
#
# Epoch 00122: val_loss did not improve from -1049.96366
#
# Epoch 00123: val_loss did not improve from -1049.96366
#
# Epoch 00124: val_loss did not improve from -1049.96366
#
# Epoch 00125: val_loss did not improve from -1049.96366
#
# Epoch 00126: val_loss did not improve from -1049.96366
#
# Epoch 00127: val_loss did not improve from -1049.96366
#
# Epoch 00128: val_loss did not improve from -1049.96366
#
# Epoch 00129: val_loss did not improve from -1049.96366
#
# Epoch 00130: val_loss did not improve from -1049.96366
#
# Epoch 00131: val_loss did not improve from -1049.96366
#
# Epoch 00132: val_loss did not improve from -1049.96366
#
# Epoch 00133: val_loss did not improve from -1049.96366
#
# Epoch 00134: val_loss did not improve from -1049.96366
#
# Epoch 00135: val_loss did not improve from -1049.96366
#
# Epoch 00136: val_loss did not improve from -1049.96366
#
# Epoch 00137: val_loss did not improve from -1049.96366
#
# Epoch 00138: val_loss did not improve from -1049.96366
#
# Epoch 00139: val_loss did not improve from -1049.96366
#
# Epoch 00140: val_loss did not improve from -1049.96366
#
# Epoch 00141: val_loss did not improve from -1049.96366
#
# Epoch 00142: val_loss did not improve from -1049.96366
#
# Epoch 00143: val_loss did not improve from -1049.96366
#
# Epoch 00144: val_loss did not improve from -1049.96366
#
# Epoch 00145: val_loss did not improve from -1049.96366
#
# Epoch 00146: val_loss did not improve from -1049.96366
#
# Epoch 00147: val_loss did not improve from -1049.96366
#
# Epoch 00148: val_loss did not improve from -1049.96366
#
# Epoch 00149: val_loss did not improve from -1049.96366
#
# Epoch 00150: val_loss did not improve from -1049.96366
#
# Epoch 00151: val_loss did not improve from -1049.96366
#
# Epoch 00152: val_loss did not improve from -1049.96366
#
# Epoch 00153: val_loss did not improve from -1049.96366
#
# Epoch 00154: val_loss did not improve from -1049.96366
#
# Epoch 00155: val_loss did not improve from -1049.96366
#
# Epoch 00156: val_loss did not improve from -1049.96366
#
# Epoch 00157: val_loss did not improve from -1049.96366
#
# Epoch 00158: val_loss did not improve from -1049.96366
#
# Epoch 00159: val_loss did not improve from -1049.96366
#
# Epoch 00160: val_loss did not improve from -1049.96366
#
# Epoch 00161: val_loss did not improve from -1049.96366
#
# Epoch 00162: val_loss did not improve from -1049.96366
#
# Epoch 00163: val_loss did not improve from -1049.96366
#
# Epoch 00164: val_loss did not improve from -1049.96366
#
# Epoch 00165: val_loss did not improve from -1049.96366
#
# Epoch 00166: val_loss did not improve from -1049.96366
#
# Epoch 00167: val_loss did not improve from -1049.96366
#
# Epoch 00168: val_loss did not improve from -1049.96366
#
# Epoch 00169: val_loss did not improve from -1049.96366
#
# Epoch 00170: val_loss did not improve from -1049.96366
#
# Epoch 00171: val_loss did not improve from -1049.96366
#
# Epoch 00172: val_loss did not improve from -1049.96366
#
# Epoch 00173: val_loss did not improve from -1049.96366
#
# Epoch 00174: val_loss did not improve from -1049.96366
#
# Epoch 00175: val_loss did not improve from -1049.96366
#
# Epoch 00176: val_loss did not improve from -1049.96366
#
# Epoch 00177: val_loss did not improve from -1049.96366
#
# Epoch 00178: val_loss did not improve from -1049.96366
#
# Epoch 00179: val_loss did not improve from -1049.96366
#
# Epoch 00180: val_loss did not improve from -1049.96366
#
# Epoch 00181: val_loss did not improve from -1049.96366
#
# Epoch 00182: val_loss improved from -1049.96366 to -1058.10564, saving model to MDN/Model3000.hdf5
#
# Epoch 00183: val_loss did not improve from -1058.10564
#
# Epoch 00184: val_loss did not improve from -1058.10564
#
# Epoch 00185: val_loss did not improve from -1058.10564
#
# Epoch 00186: val_loss did not improve from -1058.10564
#
# Epoch 00187: val_loss did not improve from -1058.10564
#
# Epoch 00188: val_loss did not improve from -1058.10564
#
# Epoch 00189: val_loss did not improve from -1058.10564
#
# Epoch 00190: val_loss did not improve from -1058.10564
#
# Epoch 00191: val_loss did not improve from -1058.10564
#
# Epoch 00192: val_loss did not improve from -1058.10564
#
# Epoch 00193: val_loss did not improve from -1058.10564
#
# Epoch 00194: val_loss did not improve from -1058.10564
#
# Epoch 00195: val_loss did not improve from -1058.10564
#
# Epoch 00196: val_loss did not improve from -1058.10564
#
# Epoch 00197: val_loss did not improve from -1058.10564
#
# Epoch 00198: val_loss did not improve from -1058.10564
#
# Epoch 00199: val_loss did not improve from -1058.10564
#
# Epoch 00200: val_loss did not improve from -1058.10564
#
# Epoch 00201: val_loss did not improve from -1058.10564
#
# Epoch 00202: val_loss improved from -1058.10564 to -1058.35759, saving model to MDN/Model3000.hdf5
#
# Epoch 00203: val_loss did not improve from -1058.35759
#
# Epoch 00204: val_loss did not improve from -1058.35759
#
# Epoch 00205: val_loss did not improve from -1058.35759
#
# Epoch 00206: val_loss did not improve from -1058.35759
#
# Epoch 00207: val_loss did not improve from -1058.35759
#
# Epoch 00208: val_loss did not improve from -1058.35759
#
# Epoch 00209: val_loss did not improve from -1058.35759
#
# Epoch 00210: val_loss did not improve from -1058.35759
#
# Epoch 00211: val_loss did not improve from -1058.35759
#
# Epoch 00212: val_loss did not improve from -1058.35759
#
# Epoch 00213: val_loss did not improve from -1058.35759
#
# Epoch 00214: val_loss did not improve from -1058.35759
#
# Epoch 00215: val_loss did not improve from -1058.35759
#
# Epoch 00216: val_loss did not improve from -1058.35759
#
# Epoch 00217: val_loss did not improve from -1058.35759
#
# Epoch 00218: val_loss did not improve from -1058.35759
#
# Epoch 00219: val_loss did not improve from -1058.35759
#
# Epoch 00220: val_loss did not improve from -1058.35759
#
# Epoch 00221: val_loss did not improve from -1058.35759
#
# Epoch 00222: val_loss did not improve from -1058.35759
#
# Epoch 00223: val_loss did not improve from -1058.35759
#
# Epoch 00224: val_loss did not improve from -1058.35759
#
# Epoch 00225: val_loss did not improve from -1058.35759
#
# Epoch 00226: val_loss did not improve from -1058.35759
#
# Epoch 00227: val_loss did not improve from -1058.35759
#
# Epoch 00228: val_loss did not improve from -1058.35759
#
# Epoch 00229: val_loss did not improve from -1058.35759
# Epoch 00230: val_loss did not improve from -1058.35759
#
# Epoch 00231: val_loss did not improve from -1058.35759
#
# Epoch 00232: val_loss did not improve from -1058.35759
#
# Epoch 00233: val_loss did not improve from -1058.35759
#
# Epoch 00234: val_loss did not improve from -1058.35759
#
# Epoch 00235: val_loss did not improve from -1058.35759
#
# Epoch 00236: val_loss did not improve from -1058.35759
#
# Epoch 00237: val_loss did not improve from -1058.35759
#
# Epoch 00238: val_loss did not improve from -1058.35759
#
# Epoch 00239: val_loss did not improve from -1058.35759
#
# Epoch 00240: val_loss did not improve from -1058.35759
#
# Epoch 00241: val_loss did not improve from -1058.35759
#
# Epoch 00242: val_loss did not improve from -1058.35759
#
# Epoch 00243: val_loss did not improve from -1058.35759
#
# Epoch 00244: val_loss did not improve from -1058.35759
#
# Epoch 00245: val_loss did not improve from -1058.35759
#
# Epoch 00246: val_loss did not improve from -1058.35759
#
# Epoch 00247: val_loss did not improve from -1058.35759
#
# Epoch 00248: val_loss did not improve from -1058.35759
#
# Epoch 00249: val_loss did not improve from -1058.35759
#
# Epoch 00250: val_loss did not improve from -1058.35759
#
# Epoch 00251: val_loss did not improve from -1058.35759
#
# Epoch 00252: val_loss did not improve from -1058.35759
#
# Epoch 00253: val_loss did not improve from -1058.35759
#
# Epoch 00254: val_loss did not improve from -1058.35759
#
# Epoch 00255: val_loss did not improve from -1058.35759
#
# Epoch 00256: val_loss did not improve from -1058.35759
#
# Epoch 00257: val_loss did not improve from -1058.35759
#
# Epoch 00258: val_loss did not improve from -1058.35759
#
# Epoch 00259: val_loss did not improve from -1058.35759
#
# Epoch 00260: val_loss did not improve from -1058.35759
#
# Epoch 00261: val_loss did not improve from -1058.35759
#
# Epoch 00262: val_loss did not improve from -1058.35759
#
# Epoch 00263: val_loss did not improve from -1058.35759
#
# Epoch 00264: val_loss did not improve from -1058.35759
#
# Epoch 00265: val_loss did not improve from -1058.35759
#
# Epoch 00266: val_loss did not improve from -1058.35759
#
# Epoch 00267: val_loss did not improve from -1058.35759
#
# Epoch 00268: val_loss did not improve from -1058.35759
#
# Epoch 00269: val_loss did not improve from -1058.35759
#
# Epoch 00270: val_loss did not improve from -1058.35759
#
# Epoch 00271: val_loss did not improve from -1058.35759
#
# Epoch 00272: val_loss did not improve from -1058.35759
#
# Epoch 00273: val_loss did not improve from -1058.35759
#
# Epoch 00274: val_loss did not improve from -1058.35759
#
# Epoch 00275: val_loss did not improve from -1058.35759
#
# Epoch 00276: val_loss did not improve from -1058.35759
#
# Epoch 00277: val_loss did not improve from -1058.35759
#
# Epoch 00278: val_loss did not improve from -1058.35759
#
# Epoch 00279: val_loss did not improve from -1058.35759
#
# Epoch 00280: val_loss did not improve from -1058.35759
#
# Epoch 00281: val_loss did not improve from -1058.35759
#
# Epoch 00282: val_loss did not improve from -1058.35759
#
# Epoch 00283: val_loss did not improve from -1058.35759
#
# Epoch 00284: val_loss did not improve from -1058.35759
#
# Epoch 00285: val_loss did not improve from -1058.35759
#
# Epoch 00286: val_loss did not improve from -1058.35759
#
# Epoch 00287: val_loss did not improve from -1058.35759
#
# Epoch 00288: val_loss did not improve from -1058.35759
#
# Epoch 00289: val_loss did not improve from -1058.35759
#
# Epoch 00290: val_loss did not improve from -1058.35759
#
# Epoch 00291: val_loss did not improve from -1058.35759
#
# Epoch 00292: val_loss did not improve from -1058.35759
#
# Epoch 00293: val_loss did not improve from -1058.35759
#
# Epoch 00294: val_loss did not improve from -1058.35759
#
# Epoch 00295: val_loss did not improve from -1058.35759
#
# Epoch 00296: val_loss did not improve from -1058.35759
#
# Epoch 00297: val_loss did not improve from -1058.35759
#
# Epoch 00298: val_loss did not improve from -1058.35759
#
# Epoch 00299: val_loss did not improve from -1058.35759
#
# Epoch 00300: val_loss did not improve from -1058.35759
#
# Epoch 00301: val_loss improved from -1058.35759 to -1064.09869, saving model to MDN/Model3000.hdf5
#
# Epoch 00302: val_loss did not improve from -1064.09869
#
# Epoch 00303: val_loss did not improve from -1064.09869
#
# Epoch 00304: val_loss did not improve from -1064.09869
#
# Epoch 00305: val_loss did not improve from -1064.09869
#
# Epoch 00306: val_loss did not improve from -1064.09869
#
# Epoch 00307: val_loss did not improve from -1064.09869
#
# Epoch 00308: val_loss did not improve from -1064.09869
#
# Epoch 00309: val_loss did not improve from -1064.09869
#
# Epoch 00310: val_loss improved from -1064.09869 to -1069.38560, saving model to MDN/Model3000.hdf5
#
# Epoch 00311: val_loss did not improve from -1069.38560
#
# Epoch 00312: val_loss did not improve from -1069.38560
#
# Epoch 00313: val_loss did not improve from -1069.38560
#
# Epoch 00314: val_loss did not improve from -1069.38560
#
# Epoch 00315: val_loss did not improve from -1069.38560
#
# Epoch 00316: val_loss did not improve from -1069.38560
#
# Epoch 00317: val_loss did not improve from -1069.38560
#
# Epoch 00318: val_loss did not improve from -1069.38560
#
# Epoch 00319: val_loss did not improve from -1069.38560
#
# Epoch 00320: val_loss did not improve from -1069.38560
#
# Epoch 00321: val_loss did not improve from -1069.38560
#
# Epoch 00322: val_loss did not improve from -1069.38560
#
# Epoch 00323: val_loss did not improve from -1069.38560
#
# Epoch 00324: val_loss did not improve from -1069.38560
#
# Epoch 00325: val_loss did not improve from -1069.38560
#
# Epoch 00326: val_loss did not improve from -1069.38560
#
# Epoch 00327: val_loss did not improve from -1069.38560
#
# Epoch 00328: val_loss did not improve from -1069.38560
#
# Epoch 00329: val_loss did not improve from -1069.38560
#
# Epoch 00330: val_loss did not improve from -1069.38560
#
# Epoch 00331: val_loss did not improve from -1069.38560
#
# Epoch 00332: val_loss did not improve from -1069.38560
#
# Epoch 00333: val_loss did not improve from -1069.38560
#
# Epoch 00334: val_loss did not improve from -1069.38560
#
# Epoch 00335: val_loss did not improve from -1069.38560
#
# Epoch 00336: val_loss did not improve from -1069.38560
#
# Epoch 00337: val_loss did not improve from -1069.38560
#
# Epoch 00338: val_loss did not improve from -1069.38560
#
# Epoch 00339: val_loss did not improve from -1069.38560
#
# Epoch 00340: val_loss did not improve from -1069.38560
#
# Epoch 00341: val_loss did not improve from -1069.38560
#
# Epoch 00342: val_loss did not improve from -1069.38560
#
# Epoch 00343: val_loss did not improve from -1069.38560
#
# Epoch 00344: val_loss did not improve from -1069.38560
#
# Epoch 00345: val_loss did not improve from -1069.38560
#
# Epoch 00346: val_loss did not improve from -1069.38560
#
# Epoch 00347: val_loss did not improve from -1069.38560
#
# Epoch 00348: val_loss did not improve from -1069.38560
#
# Epoch 00349: val_loss did not improve from -1069.38560
#
# Epoch 00350: val_loss did not improve from -1069.38560
#
# Epoch 00351: val_loss did not improve from -1069.38560
#
# Epoch 00352: val_loss did not improve from -1069.38560
#
# Epoch 00353: val_loss did not improve from -1069.38560
#
# Epoch 00354: val_loss did not improve from -1069.38560
#
# Epoch 00355: val_loss did not improve from -1069.38560
#
# Epoch 00356: val_loss did not improve from -1069.38560
#
# Epoch 00357: val_loss did not improve from -1069.38560
#
# Epoch 00358: val_loss did not improve from -1069.38560
#
# Epoch 00359: val_loss did not improve from -1069.38560
#
# Epoch 00360: val_loss did not improve from -1069.38560
#
# Epoch 00361: val_loss did not improve from -1069.38560
#
# Epoch 00362: val_loss did not improve from -1069.38560
#
# Epoch 00363: val_loss did not improve from -1069.38560
#
# Epoch 00364: val_loss did not improve from -1069.38560
#
# Epoch 00365: val_loss did not improve from -1069.38560
#
# Epoch 00366: val_loss did not improve from -1069.38560
#
# Epoch 00367: val_loss did not improve from -1069.38560
#
# Epoch 00368: val_loss did not improve from -1069.38560
#
# Epoch 00369: val_loss did not improve from -1069.38560
#
# Epoch 00370: val_loss did not improve from -1069.38560
#
# Epoch 00371: val_loss did not improve from -1069.38560
#
# Epoch 00372: val_loss did not improve from -1069.38560
#
# Epoch 00373: val_loss did not improve from -1069.38560
#
# Epoch 00374: val_loss did not improve from -1069.38560
# Epoch 00375: val_loss did not improve from -1069.38560
#
# Epoch 00376: val_loss did not improve from -1069.38560
#
# Epoch 00377: val_loss did not improve from -1069.38560
#
# Epoch 00378: val_loss did not improve from -1069.38560
#
# Epoch 00379: val_loss did not improve from -1069.38560
#
# Epoch 00380: val_loss did not improve from -1069.38560
#
# Epoch 00381: val_loss did not improve from -1069.38560
#
# Epoch 00382: val_loss did not improve from -1069.38560
#
# Epoch 00383: val_loss did not improve from -1069.38560
#
# Epoch 00384: val_loss did not improve from -1069.38560
#
# Epoch 00385: val_loss did not improve from -1069.38560
#
# Epoch 00386: val_loss did not improve from -1069.38560
#
# Epoch 00387: val_loss did not improve from -1069.38560
#
# Epoch 00388: val_loss did not improve from -1069.38560
#
# Epoch 00389: val_loss did not improve from -1069.38560
#
# Epoch 00390: val_loss did not improve from -1069.38560
#
# Epoch 00391: val_loss did not improve from -1069.38560
#
# Epoch 00392: val_loss did not improve from -1069.38560
#
# Epoch 00393: val_loss did not improve from -1069.38560
#
# Epoch 00394: val_loss did not improve from -1069.38560
#
# Epoch 00395: val_loss did not improve from -1069.38560
#
# Epoch 00396: val_loss did not improve from -1069.38560
#
# Epoch 00397: val_loss did not improve from -1069.38560
#
# Epoch 00398: val_loss did not improve from -1069.38560
#
# Epoch 00399: val_loss did not improve from -1069.38560
#
# Epoch 00400: val_loss did not improve from -1069.38560
#
# Epoch 00401: val_loss did not improve from -1069.38560
#
# Epoch 00402: val_loss did not improve from -1069.38560
#
# Epoch 00403: val_loss did not improve from -1069.38560
#
# Epoch 00404: val_loss did not improve from -1069.38560
#
# Epoch 00405: val_loss did not improve from -1069.38560
#
# Epoch 00406: val_loss did not improve from -1069.38560
#
# Epoch 00407: val_loss did not improve from -1069.38560
#
# Epoch 00408: val_loss did not improve from -1069.38560
#
# Epoch 00409: val_loss did not improve from -1069.38560
#
# Epoch 00410: val_loss did not improve from -1069.38560
#
# Epoch 00411: val_loss did not improve from -1069.38560
#
# Epoch 00412: val_loss did not improve from -1069.38560
#
# Epoch 00413: val_loss did not improve from -1069.38560
#
# Epoch 00414: val_loss did not improve from -1069.38560
#
# Epoch 00415: val_loss did not improve from -1069.38560
#
# Epoch 00416: val_loss did not improve from -1069.38560
#
# Epoch 00417: val_loss did not improve from -1069.38560
#
# Epoch 00418: val_loss did not improve from -1069.38560
#
# Epoch 00419: val_loss did not improve from -1069.38560
#
# Epoch 00420: val_loss did not improve from -1069.38560
#
# Epoch 00421: val_loss did not improve from -1069.38560
#
# Epoch 00422: val_loss did not improve from -1069.38560
#
# Epoch 00423: val_loss did not improve from -1069.38560
#
# Epoch 00424: val_loss did not improve from -1069.38560
#
# Epoch 00425: val_loss did not improve from -1069.38560
#
# Epoch 00426: val_loss did not improve from -1069.38560
#
# Epoch 00427: val_loss did not improve from -1069.38560
#
# Epoch 00428: val_loss did not improve from -1069.38560
#
# Epoch 00429: val_loss did not improve from -1069.38560
#
# Epoch 00430: val_loss did not improve from -1069.38560
#
# Epoch 00431: val_loss did not improve from -1069.38560
#
# Epoch 00432: val_loss did not improve from -1069.38560
#
# Epoch 00433: val_loss did not improve from -1069.38560
#
# Epoch 00434: val_loss did not improve from -1069.38560
#
# Epoch 00435: val_loss did not improve from -1069.38560
#
# Epoch 00436: val_loss did not improve from -1069.38560
#
# Epoch 00437: val_loss did not improve from -1069.38560
#
# Epoch 00438: val_loss did not improve from -1069.38560
#
# Epoch 00439: val_loss did not improve from -1069.38560
#
# Epoch 00440: val_loss did not improve from -1069.38560
#
# Epoch 00441: val_loss did not improve from -1069.38560
#
# Epoch 00442: val_loss did not improve from -1069.38560
#
# Epoch 00443: val_loss did not improve from -1069.38560
#
# Epoch 00444: val_loss did not improve from -1069.38560
#
# Epoch 00445: val_loss did not improve from -1069.38560
#
# Epoch 00446: val_loss did not improve from -1069.38560
#
# Epoch 00447: val_loss did not improve from -1069.38560
#
# Epoch 00448: val_loss did not improve from -1069.38560
#
# Epoch 00449: val_loss did not improve from -1069.38560
#
# Epoch 00450: val_loss did not improve from -1069.38560
#
# Epoch 00451: val_loss did not improve from -1069.38560
#
# Epoch 00452: val_loss did not improve from -1069.38560
#
# Epoch 00453: val_loss did not improve from -1069.38560
#
# Epoch 00454: val_loss did not improve from -1069.38560
#
# Epoch 00455: val_loss did not improve from -1069.38560
#
# Epoch 00456: val_loss did not improve from -1069.38560
#
# Epoch 00457: val_loss did not improve from -1069.38560
#
# Epoch 00458: val_loss did not improve from -1069.38560
#
# Epoch 00459: val_loss did not improve from -1069.38560
#
# Epoch 00460: val_loss did not improve from -1069.38560
#
# Epoch 00461: val_loss did not improve from -1069.38560
#
# Epoch 00462: val_loss did not improve from -1069.38560
#
# Epoch 00463: val_loss did not improve from -1069.38560
#
# Epoch 00464: val_loss did not improve from -1069.38560
#
# Epoch 00465: val_loss did not improve from -1069.38560
#
# Epoch 00466: val_loss did not improve from -1069.38560
#
# Epoch 00467: val_loss did not improve from -1069.38560
#
# Epoch 00468: val_loss did not improve from -1069.38560
#
# Epoch 00469: val_loss did not improve from -1069.38560
#
# Epoch 00470: val_loss did not improve from -1069.38560
#
# Epoch 00471: val_loss did not improve from -1069.38560
#
# Epoch 00472: val_loss did not improve from -1069.38560
#
# Epoch 00473: val_loss did not improve from -1069.38560
#
# Epoch 00474: val_loss did not improve from -1069.38560
#
# Epoch 00475: val_loss did not improve from -1069.38560
#
# Epoch 00476: val_loss did not improve from -1069.38560
#
# Epoch 00477: val_loss did not improve from -1069.38560
#
# Epoch 00478: val_loss did not improve from -1069.38560
#
# Epoch 00479: val_loss did not improve from -1069.38560
#
# Epoch 00480: val_loss did not improve from -1069.38560
#
# Epoch 00481: val_loss did not improve from -1069.38560
#
# Epoch 00482: val_loss did not improve from -1069.38560
#
# Epoch 00483: val_loss did not improve from -1069.38560
#
# Epoch 00484: val_loss did not improve from -1069.38560
#
# Epoch 00485: val_loss did not improve from -1069.38560
#
# Epoch 00486: val_loss did not improve from -1069.38560
#
# Epoch 00487: val_loss did not improve from -1069.38560
#
# Epoch 00488: val_loss did not improve from -1069.38560
#
# Epoch 00489: val_loss did not improve from -1069.38560
#
# Epoch 00490: val_loss did not improve from -1069.38560
#
# Epoch 00491: val_loss did not improve from -1069.38560
#
# Epoch 00492: val_loss did not improve from -1069.38560
#
# Epoch 00493: val_loss did not improve from -1069.38560
#
# Epoch 00494: val_loss did not improve from -1069.38560
#
# Epoch 00495: val_loss did not improve from -1069.38560
#
# Epoch 00496: val_loss did not improve from -1069.38560
#
# Epoch 00497: val_loss did not improve from -1069.38560
#
# Epoch 00498: val_loss did not improve from -1069.38560
#
# Epoch 00499: val_loss did not improve from -1069.38560
#
# Epoch 00500: val_loss did not improve from -1069.38560
#
# Epoch 00501: val_loss did not improve from -1069.38560
#
# Epoch 00502: val_loss did not improve from -1069.38560
#
# Epoch 00503: val_loss did not improve from -1069.38560
#
# Epoch 00504: val_loss did not improve from -1069.38560
#
# Epoch 00505: val_loss did not improve from -1069.38560
#
# Epoch 00506: val_loss did not improve from -1069.38560
#
# Epoch 00507: val_loss did not improve from -1069.38560
#
# Epoch 00508: val_loss did not improve from -1069.38560
#
# Epoch 00509: val_loss did not improve from -1069.38560
#
# Epoch 00510: val_loss did not improve from -1069.38560
#
# Epoch 00511: val_loss did not improve from -1069.38560
#
# Epoch 00512: val_loss did not improve from -1069.38560
#
# Epoch 00513: val_loss did not improve from -1069.38560
#
# Epoch 00514: val_loss did not improve from -1069.38560
#
# Epoch 00515: val_loss did not improve from -1069.38560
#
# Epoch 00516: val_loss did not improve from -1069.38560
#
# Epoch 00517: val_loss did not improve from -1069.38560
#
# Epoch 00518: val_loss did not improve from -1069.38560
#
# Epoch 00519: val_loss did not improve from -1069.38560
#
# Epoch 00520: val_loss did not improve from -1069.38560
#
# Epoch 00521: val_loss did not improve from -1069.38560
# Epoch 00522: val_loss did not improve from -1069.38560
#
# Epoch 00523: val_loss did not improve from -1069.38560
#
# Epoch 00524: val_loss did not improve from -1069.38560
#
# Epoch 00525: val_loss did not improve from -1069.38560
#
# Epoch 00526: val_loss did not improve from -1069.38560
#
# Epoch 00527: val_loss did not improve from -1069.38560
#
# Epoch 00528: val_loss did not improve from -1069.38560
#
# Epoch 00529: val_loss did not improve from -1069.38560
#
# Epoch 00530: val_loss did not improve from -1069.38560
#
# Epoch 00531: val_loss did not improve from -1069.38560
#
# Epoch 00532: val_loss did not improve from -1069.38560
#
# Epoch 00533: val_loss did not improve from -1069.38560
#
# Epoch 00534: val_loss did not improve from -1069.38560
#
# Epoch 00535: val_loss did not improve from -1069.38560
#
# Epoch 00536: val_loss did not improve from -1069.38560
#
# Epoch 00537: val_loss did not improve from -1069.38560
#
# Epoch 00538: val_loss did not improve from -1069.38560
#
# Epoch 00539: val_loss did not improve from -1069.38560
#
# Epoch 00540: val_loss did not improve from -1069.38560
#
# Epoch 00541: val_loss did not improve from -1069.38560
#
# Epoch 00542: val_loss did not improve from -1069.38560
#
# Epoch 00543: val_loss did not improve from -1069.38560
#
# Epoch 00544: val_loss did not improve from -1069.38560
#
# Epoch 00545: val_loss did not improve from -1069.38560
#
# Epoch 00546: val_loss did not improve from -1069.38560
#
# Epoch 00547: val_loss did not improve from -1069.38560
#
# Epoch 00548: val_loss did not improve from -1069.38560
#
# Epoch 00549: val_loss did not improve from -1069.38560
#
# Epoch 00550: val_loss did not improve from -1069.38560
#
# Epoch 00551: val_loss did not improve from -1069.38560
#
# Epoch 00552: val_loss did not improve from -1069.38560
#
# Epoch 00553: val_loss did not improve from -1069.38560
#
# Epoch 00554: val_loss did not improve from -1069.38560
#
# Epoch 00555: val_loss did not improve from -1069.38560
#
# Epoch 00556: val_loss did not improve from -1069.38560
#
# Epoch 00557: val_loss did not improve from -1069.38560
#
# Epoch 00558: val_loss did not improve from -1069.38560
#
# Epoch 00559: val_loss did not improve from -1069.38560
#
# Epoch 00560: val_loss did not improve from -1069.38560
#
# Epoch 00561: val_loss did not improve from -1069.38560
#
# Epoch 00562: val_loss did not improve from -1069.38560
#
# Epoch 00563: val_loss did not improve from -1069.38560
#
# Epoch 00564: val_loss did not improve from -1069.38560
#
# Epoch 00565: val_loss did not improve from -1069.38560
#
# Epoch 00566: val_loss did not improve from -1069.38560
#
# Epoch 00567: val_loss did not improve from -1069.38560
#
# Epoch 00568: val_loss did not improve from -1069.38560
#
# Epoch 00569: val_loss did not improve from -1069.38560
#
# Epoch 00570: val_loss did not improve from -1069.38560
#
# Epoch 00571: val_loss did not improve from -1069.38560
#
# Epoch 00572: val_loss did not improve from -1069.38560
#
# Epoch 00573: val_loss did not improve from -1069.38560
#
# Epoch 00574: val_loss did not improve from -1069.38560
#
# Epoch 00575: val_loss did not improve from -1069.38560
#
# Epoch 00576: val_loss did not improve from -1069.38560
#
# Epoch 00577: val_loss did not improve from -1069.38560
#
# Epoch 00578: val_loss did not improve from -1069.38560
#
# Epoch 00579: val_loss did not improve from -1069.38560
#
# Epoch 00580: val_loss did not improve from -1069.38560
#
# Epoch 00581: val_loss did not improve from -1069.38560
#
# Epoch 00582: val_loss did not improve from -1069.38560
#
# Epoch 00583: val_loss did not improve from -1069.38560
#
# Epoch 00584: val_loss did not improve from -1069.38560
#
# Epoch 00585: val_loss did not improve from -1069.38560
#
# Epoch 00586: val_loss did not improve from -1069.38560
#
# Epoch 00587: val_loss did not improve from -1069.38560
#
# Epoch 00588: val_loss did not improve from -1069.38560
#
# Epoch 00589: val_loss did not improve from -1069.38560
#
# Epoch 00590: val_loss did not improve from -1069.38560
#
# Epoch 00591: val_loss did not improve from -1069.38560
#
# Epoch 00592: val_loss did not improve from -1069.38560
#
# Epoch 00593: val_loss improved from -1069.38560 to -1074.55550, saving model to MDN/Model3000.hdf5
#
# Epoch 00594: val_loss did not improve from -1074.55550
#
# Epoch 00595: val_loss did not improve from -1074.55550
#
# Epoch 00596: val_loss did not improve from -1074.55550
#
# Epoch 00597: val_loss did not improve from -1074.55550
#
# Epoch 00598: val_loss did not improve from -1074.55550
#
# Epoch 00599: val_loss did not improve from -1074.55550
#
# Epoch 00600: val_loss did not improve from -1074.55550
#
# Epoch 00601: val_loss did not improve from -1074.55550
#
# Epoch 00602: val_loss did not improve from -1074.55550
#
# Epoch 00603: val_loss did not improve from -1074.55550
#
# Epoch 00604: val_loss did not improve from -1074.55550
#
# Epoch 00605: val_loss did not improve from -1074.55550
#
# Epoch 00606: val_loss did not improve from -1074.55550
#
# Epoch 00607: val_loss did not improve from -1074.55550
#
# Epoch 00608: val_loss did not improve from -1074.55550
#
# Epoch 00609: val_loss did not improve from -1074.55550
#
# Epoch 00610: val_loss did not improve from -1074.55550
#
# Epoch 00611: val_loss did not improve from -1074.55550
#
# Epoch 00612: val_loss did not improve from -1074.55550
#
# Epoch 00613: val_loss did not improve from -1074.55550
#
# Epoch 00614: val_loss did not improve from -1074.55550
#
# Epoch 00615: val_loss did not improve from -1074.55550
#
# Epoch 00616: val_loss did not improve from -1074.55550
#
# Epoch 00617: val_loss did not improve from -1074.55550
#
# Epoch 00618: val_loss did not improve from -1074.55550
#
# Epoch 00619: val_loss did not improve from -1074.55550
#
# Epoch 00620: val_loss did not improve from -1074.55550
#
# Epoch 00621: val_loss did not improve from -1074.55550
#
# Epoch 00622: val_loss did not improve from -1074.55550
#
# Epoch 00623: val_loss did not improve from -1074.55550
#
# Epoch 00624: val_loss did not improve from -1074.55550
#
# Epoch 00625: val_loss did not improve from -1074.55550
#
# Epoch 00626: val_loss did not improve from -1074.55550
#
# Epoch 00627: val_loss did not improve from -1074.55550
#
# Epoch 00628: val_loss did not improve from -1074.55550
#
# Epoch 00629: val_loss did not improve from -1074.55550
#
# Epoch 00630: val_loss did not improve from -1074.55550
#
# Epoch 00631: val_loss did not improve from -1074.55550
#
# Epoch 00632: val_loss did not improve from -1074.55550
#
# Epoch 00633: val_loss did not improve from -1074.55550
#
# Epoch 00634: val_loss did not improve from -1074.55550
#
# Epoch 00635: val_loss did not improve from -1074.55550
#
# Epoch 00636: val_loss did not improve from -1074.55550
#
# Epoch 00637: val_loss did not improve from -1074.55550
#
# Epoch 00638: val_loss did not improve from -1074.55550
#
# Epoch 00639: val_loss did not improve from -1074.55550
#
# Epoch 00640: val_loss did not improve from -1074.55550
#
# Epoch 00641: val_loss did not improve from -1074.55550
#
# Epoch 00642: val_loss did not improve from -1074.55550
#
# Epoch 00643: val_loss did not improve from -1074.55550
#
# Epoch 00644: val_loss did not improve from -1074.55550
#
# Epoch 00645: val_loss did not improve from -1074.55550
#
# Epoch 00646: val_loss did not improve from -1074.55550
#
# Epoch 00647: val_loss did not improve from -1074.55550
#
# Epoch 00648: val_loss did not improve from -1074.55550
#
# Epoch 00649: val_loss did not improve from -1074.55550
#
# Epoch 00650: val_loss did not improve from -1074.55550
#
# Epoch 00651: val_loss did not improve from -1074.55550
#
# Epoch 00652: val_loss did not improve from -1074.55550
#
# Epoch 00653: val_loss did not improve from -1074.55550
#
# Epoch 00654: val_loss did not improve from -1074.55550
#
# Epoch 00655: val_loss did not improve from -1074.55550
#
# Epoch 00656: val_loss did not improve from -1074.55550
#
# Epoch 00657: val_loss did not improve from -1074.55550
#
# Epoch 00658: val_loss did not improve from -1074.55550
#
# Epoch 00659: val_loss did not improve from -1074.55550
#
# Epoch 00660: val_loss did not improve from -1074.55550
#
# Epoch 00661: val_loss did not improve from -1074.55550
#
# Epoch 00662: val_loss did not improve from -1074.55550
#
# Epoch 00663: val_loss did not improve from -1074.55550
#
# Epoch 00664: val_loss did not improve from -1074.55550
#
# Epoch 00665: val_loss did not improve from -1074.55550
#
# Epoch 00666: val_loss did not improve from -1074.55550
#
# Epoch 00667: val_loss did not improve from -1074.55550
# Epoch 00668: val_loss did not improve from -1074.55550
#
# Epoch 00669: val_loss did not improve from -1074.55550
#
# Epoch 00670: val_loss did not improve from -1074.55550
#
# Epoch 00671: val_loss did not improve from -1074.55550
#
# Epoch 00672: val_loss did not improve from -1074.55550
#
# Epoch 00673: val_loss did not improve from -1074.55550
#
# Epoch 00674: val_loss did not improve from -1074.55550
#
# Epoch 00675: val_loss did not improve from -1074.55550
#
# Epoch 00676: val_loss did not improve from -1074.55550
#
# Epoch 00677: val_loss did not improve from -1074.55550
#
# Epoch 00678: val_loss did not improve from -1074.55550
#
# Epoch 00679: val_loss did not improve from -1074.55550
#
# Epoch 00680: val_loss did not improve from -1074.55550
#
# Epoch 00681: val_loss did not improve from -1074.55550
#
# Epoch 00682: val_loss did not improve from -1074.55550
#
# Epoch 00683: val_loss did not improve from -1074.55550
#
# Epoch 00684: val_loss did not improve from -1074.55550
#
# Epoch 00685: val_loss did not improve from -1074.55550
#
# Epoch 00686: val_loss improved from -1074.55550 to -1074.74284, saving model to MDN/Model3000.hdf5
#
# Epoch 00687: val_loss did not improve from -1074.74284
#
# Epoch 00688: val_loss did not improve from -1074.74284
#
# Epoch 00689: val_loss did not improve from -1074.74284
#
# Epoch 00690: val_loss did not improve from -1074.74284
#
# Epoch 00691: val_loss did not improve from -1074.74284
#
# Epoch 00692: val_loss did not improve from -1074.74284
#
# Epoch 00693: val_loss did not improve from -1074.74284
#
# Epoch 00694: val_loss did not improve from -1074.74284
#
# Epoch 00695: val_loss did not improve from -1074.74284
#
# Epoch 00696: val_loss did not improve from -1074.74284
#
# Epoch 00697: val_loss did not improve from -1074.74284
#
# Epoch 00698: val_loss did not improve from -1074.74284
#
# Epoch 00699: val_loss did not improve from -1074.74284
#
# Epoch 00700: val_loss did not improve from -1074.74284
#
# Epoch 00701: val_loss did not improve from -1074.74284
#
# Epoch 00702: val_loss did not improve from -1074.74284
#
# Epoch 00703: val_loss did not improve from -1074.74284
#
# Epoch 00704: val_loss did not improve from -1074.74284
#
# Epoch 00705: val_loss did not improve from -1074.74284
#
# Epoch 00706: val_loss did not improve from -1074.74284
#
# Epoch 00707: val_loss did not improve from -1074.74284
#
# Epoch 00708: val_loss did not improve from -1074.74284
#
# Epoch 00709: val_loss did not improve from -1074.74284
#
# Epoch 00710: val_loss did not improve from -1074.74284
#
# Epoch 00711: val_loss did not improve from -1074.74284
#
# Epoch 00712: val_loss did not improve from -1074.74284
#
# Epoch 00713: val_loss did not improve from -1074.74284
#
# Epoch 00714: val_loss did not improve from -1074.74284
#
# Epoch 00715: val_loss did not improve from -1074.74284
#
# Epoch 00716: val_loss did not improve from -1074.74284
#
# Epoch 00717: val_loss improved from -1074.74284 to -1076.49267, saving model to MDN/Model3000.hdf5
#
# Epoch 00718: val_loss did not improve from -1076.49267
#
# Epoch 00719: val_loss did not improve from -1076.49267
#
# Epoch 00720: val_loss did not improve from -1076.49267
#
# Epoch 00721: val_loss did not improve from -1076.49267
#
# Epoch 00722: val_loss did not improve from -1076.49267
#
# Epoch 00723: val_loss did not improve from -1076.49267
#
# Epoch 00724: val_loss did not improve from -1076.49267
#
# Epoch 00725: val_loss did not improve from -1076.49267
#
# Epoch 00726: val_loss did not improve from -1076.49267
#
# Epoch 00727: val_loss did not improve from -1076.49267
#
# Epoch 00728: val_loss did not improve from -1076.49267
#
# Epoch 00729: val_loss did not improve from -1076.49267
#
# Epoch 00730: val_loss did not improve from -1076.49267
#
# Epoch 00731: val_loss did not improve from -1076.49267
#
# Epoch 00732: val_loss did not improve from -1076.49267
#
# Epoch 00733: val_loss did not improve from -1076.49267
#
# Epoch 00734: val_loss did not improve from -1076.49267
#
# Epoch 00735: val_loss did not improve from -1076.49267
#
# Epoch 00736: val_loss did not improve from -1076.49267
#
# Epoch 00737: val_loss did not improve from -1076.49267
#
# Epoch 00738: val_loss did not improve from -1076.49267
#
# Epoch 00739: val_loss did not improve from -1076.49267
#
# Epoch 00740: val_loss did not improve from -1076.49267
#
# Epoch 00741: val_loss did not improve from -1076.49267
#
# Epoch 00742: val_loss did not improve from -1076.49267
#
# Epoch 00743: val_loss did not improve from -1076.49267
#
# Epoch 00744: val_loss did not improve from -1076.49267
#
# Epoch 00745: val_loss did not improve from -1076.49267
#
# Epoch 00746: val_loss did not improve from -1076.49267
#
# Epoch 00747: val_loss did not improve from -1076.49267
#
# Epoch 00748: val_loss did not improve from -1076.49267
#
# Epoch 00749: val_loss did not improve from -1076.49267
#
# Epoch 00750: val_loss did not improve from -1076.49267
#
# Epoch 00751: val_loss did not improve from -1076.49267
#
# Epoch 00752: val_loss did not improve from -1076.49267
#
# Epoch 00753: val_loss did not improve from -1076.49267
#
# Epoch 00754: val_loss did not improve from -1076.49267
#
# Epoch 00755: val_loss did not improve from -1076.49267
#
# Epoch 00756: val_loss did not improve from -1076.49267
#
# Epoch 00757: val_loss did not improve from -1076.49267
#
# Epoch 00758: val_loss did not improve from -1076.49267
#
# Epoch 00759: val_loss did not improve from -1076.49267
#
# Epoch 00760: val_loss did not improve from -1076.49267
#
# Epoch 00761: val_loss did not improve from -1076.49267
#
# Epoch 00762: val_loss did not improve from -1076.49267
#
# Epoch 00763: val_loss did not improve from -1076.49267
#
# Epoch 00764: val_loss did not improve from -1076.49267
#
# Epoch 00765: val_loss did not improve from -1076.49267
#
# Epoch 00766: val_loss did not improve from -1076.49267
#
# Epoch 00767: val_loss did not improve from -1076.49267
#
# Epoch 00768: val_loss did not improve from -1076.49267
#
# Epoch 00769: val_loss did not improve from -1076.49267
#
# Epoch 00770: val_loss did not improve from -1076.49267
#
# Epoch 00771: val_loss did not improve from -1076.49267
#
# Epoch 00772: val_loss did not improve from -1076.49267
#
# Epoch 00773: val_loss did not improve from -1076.49267
#
# Epoch 00774: val_loss did not improve from -1076.49267
#
# Epoch 00775: val_loss did not improve from -1076.49267
#
# Epoch 00776: val_loss did not improve from -1076.49267
#
# Epoch 00777: val_loss did not improve from -1076.49267
#
# Epoch 00778: val_loss did not improve from -1076.49267
#
# Epoch 00779: val_loss did not improve from -1076.49267
#
# Epoch 00780: val_loss did not improve from -1076.49267
#
# Epoch 00781: val_loss did not improve from -1076.49267
#
# Epoch 00782: val_loss did not improve from -1076.49267
#
# Epoch 00783: val_loss did not improve from -1076.49267
#
# Epoch 00784: val_loss did not improve from -1076.49267
#
# Epoch 00785: val_loss did not improve from -1076.49267
#
# Epoch 00786: val_loss did not improve from -1076.49267
#
# Epoch 00787: val_loss did not improve from -1076.49267
#
# Epoch 00788: val_loss did not improve from -1076.49267
#
# ...
#
# Epoch 01220: val_loss did not improve from -1095.42023
#
# Epoch 01221: val_loss did not improve from -1095.42023
#
# Epoch 01222: val_loss did not improve from -1095.42023
#
# Epoch 01223: val_loss did not improve from -1095.42023
#
# Epoch 01224: val_loss did not improve from -1095.42023
#
# Epoch 01225: val_loss did not improve from -1095.42023
#
# Epoch 01226: val_loss did not improve from -1095.42023
#
# Epoch 01227: val_loss did not improve from -1095.42023
#
# Epoch 01228: val_loss did not improve from -1095.42023
#
# Epoch 01229: val_loss did not improve from -1095.42023
#
# Epoch 01230: val_loss did not improve from -1095.42023
#
# Epoch 01231: val_loss did not improve from -1095.42023
#
# Epoch 01232: val_loss did not improve from -1095.42023
#
# Epoch 01233: val_loss did not improve from -1095.42023
#
# Epoch 01234: val_loss did not improve from -1095.42023
#
# Epoch 01235: val_loss did not improve from -1095.42023
#
# Epoch 01236: val_loss did not improve from -1095.42023
#
# Epoch 01237: val_loss did not improve from -1095.42023
#
# Epoch 01238: val_loss did not improve from -1095.42023
#
# Epoch 01239: val_loss did not improve from -1095.42023
#
# Epoch 01240: val_loss did not improve from -1095.42023
#
# Epoch 01241: val_loss did not improve from -1095.42023
#
# Epoch 01242: val_loss did not improve from -1095.42023
#
# Epoch 01243: val_loss did not improve from -1095.42023
#
# Epoch 01244: val_loss did not improve from -1095.42023
#
# Epoch 01245: val_loss did not improve from -1095.42023
#
# Epoch 01246: val_loss did not improve from -1095.42023
#
# Epoch 01247: val_loss did not improve from -1095.42023
# Epoch 01248: val_loss did not improve from -1095.42023
#
# Epoch 01249: val_loss did not improve from -1095.42023
#
# Epoch 01250: val_loss did not improve from -1095.42023
#
# Epoch 01251: val_loss did not improve from -1095.42023
#
# Epoch 01252: val_loss did not improve from -1095.42023
#
# Epoch 01253: val_loss did not improve from -1095.42023
#
# Epoch 01254: val_loss did not improve from -1095.42023
#
# Epoch 01255: val_loss did not improve from -1095.42023
#
# Epoch 01256: val_loss did not improve from -1095.42023
#
# Epoch 01257: val_loss did not improve from -1095.42023
#
# Epoch 01258: val_loss did not improve from -1095.42023
#
# Epoch 01259: val_loss did not improve from -1095.42023
#
# Epoch 01260: val_loss did not improve from -1095.42023
#
# Epoch 01261: val_loss did not improve from -1095.42023
#
# Epoch 01262: val_loss did not improve from -1095.42023
#
# Epoch 01263: val_loss did not improve from -1095.42023
#
# Epoch 01264: val_loss did not improve from -1095.42023
#
# Epoch 01265: val_loss did not improve from -1095.42023
#
# Epoch 01266: val_loss did not improve from -1095.42023
#
# Epoch 01267: val_loss did not improve from -1095.42023
#
# Epoch 01268: val_loss did not improve from -1095.42023
#
# Epoch 01269: val_loss did not improve from -1095.42023
#
# Epoch 01270: val_loss did not improve from -1095.42023
#
# Epoch 01271: val_loss did not improve from -1095.42023
#
# Epoch 01272: val_loss did not improve from -1095.42023
#
# Epoch 01273: val_loss did not improve from -1095.42023
#
# Epoch 01274: val_loss did not improve from -1095.42023
#
# Epoch 01275: val_loss did not improve from -1095.42023
#
# Epoch 01276: val_loss did not improve from -1095.42023
#
# Epoch 01277: val_loss did not improve from -1095.42023
#
# Epoch 01278: val_loss did not improve from -1095.42023
#
# Epoch 01279: val_loss did not improve from -1095.42023
#
# Epoch 01280: val_loss did not improve from -1095.42023
#
# Epoch 01281: val_loss did not improve from -1095.42023
#
# Epoch 01282: val_loss did not improve from -1095.42023
#
# Epoch 01283: val_loss did not improve from -1095.42023
#
# Epoch 01284: val_loss did not improve from -1095.42023
#
# Epoch 01285: val_loss did not improve from -1095.42023
#
# Epoch 01286: val_loss did not improve from -1095.42023
#
# Epoch 01287: val_loss did not improve from -1095.42023
#
# Epoch 01288: val_loss did not improve from -1095.42023
#
# Epoch 01289: val_loss did not improve from -1095.42023
#
# Epoch 01290: val_loss did not improve from -1095.42023
#
# Epoch 01291: val_loss did not improve from -1095.42023
#
# Epoch 01292: val_loss did not improve from -1095.42023
#
# Epoch 01293: val_loss did not improve from -1095.42023
#
# Epoch 01294: val_loss improved from -1095.42023 to -1097.47082, saving model to MDN/Model3000.hdf5
#
# Epoch 01295: val_loss did not improve from -1097.47082
#
# Epoch 01296: val_loss did not improve from -1097.47082
#
# Epoch 01297: val_loss did not improve from -1097.47082
#
# Epoch 01298: val_loss did not improve from -1097.47082
#
# Epoch 01299: val_loss did not improve from -1097.47082
#
# Epoch 01300: val_loss did not improve from -1097.47082
#
# Epoch 01301: val_loss did not improve from -1097.47082
#
# Epoch 01302: val_loss did not improve from -1097.47082
#
# Epoch 01303: val_loss improved from -1097.47082 to -1097.80100, saving model to MDN/Model3000.hdf5
#
# Epoch 01304: val_loss did not improve from -1097.80100
#
# Epoch 01305: val_loss did not improve from -1097.80100
#
# Epoch 01306: val_loss did not improve from -1097.80100
#
# Epoch 01307: val_loss did not improve from -1097.80100
#
# Epoch 01308: val_loss did not improve from -1097.80100
#
# Epoch 01309: val_loss did not improve from -1097.80100
#
# Epoch 01310: val_loss did not improve from -1097.80100
#
# Epoch 01311: val_loss did not improve from -1097.80100
#
# Epoch 01312: val_loss did not improve from -1097.80100
#
# Epoch 01313: val_loss did not improve from -1097.80100
#
# Epoch 01314: val_loss did not improve from -1097.80100
#
# Epoch 01315: val_loss did not improve from -1097.80100
#
# Epoch 01316: val_loss did not improve from -1097.80100
#
# Epoch 01317: val_loss did not improve from -1097.80100
#
# Epoch 01318: val_loss did not improve from -1097.80100
#
# Epoch 01319: val_loss did not improve from -1097.80100
#
# Epoch 01320: val_loss did not improve from -1097.80100
#
# Epoch 01321: val_loss did not improve from -1097.80100
#
# Epoch 01322: val_loss did not improve from -1097.80100
#
# Epoch 01323: val_loss did not improve from -1097.80100
#
# Epoch 01324: val_loss did not improve from -1097.80100
#
# Epoch 01325: val_loss did not improve from -1097.80100
#
# Epoch 01326: val_loss did not improve from -1097.80100
#
# Epoch 01327: val_loss did not improve from -1097.80100
#
# Epoch 01328: val_loss did not improve from -1097.80100
#
# Epoch 01329: val_loss did not improve from -1097.80100
#
# Epoch 01330: val_loss did not improve from -1097.80100
#
# Epoch 01331: val_loss did not improve from -1097.80100
#
# Epoch 01332: val_loss did not improve from -1097.80100
#
# Epoch 01333: val_loss did not improve from -1097.80100
#
# Epoch 01334: val_loss did not improve from -1097.80100
#
# Epoch 01335: val_loss did not improve from -1097.80100
#
# Epoch 01336: val_loss did not improve from -1097.80100
#
# Epoch 01337: val_loss did not improve from -1097.80100
#
# Epoch 01338: val_loss did not improve from -1097.80100
#
# Epoch 01339: val_loss did not improve from -1097.80100
#
# Epoch 01340: val_loss did not improve from -1097.80100
#
# Epoch 01341: val_loss did not improve from -1097.80100
#
# Epoch 01342: val_loss did not improve from -1097.80100
#
# Epoch 01343: val_loss did not improve from -1097.80100
#
# Epoch 01344: val_loss did not improve from -1097.80100
#
# Epoch 01345: val_loss did not improve from -1097.80100
#
# Epoch 01346: val_loss did not improve from -1097.80100
#
# Epoch 01347: val_loss did not improve from -1097.80100
#
# Epoch 01348: val_loss did not improve from -1097.80100
#
# Epoch 01349: val_loss did not improve from -1097.80100
#
# Epoch 01350: val_loss did not improve from -1097.80100
#
# Epoch 01351: val_loss did not improve from -1097.80100
#
# Epoch 01352: val_loss did not improve from -1097.80100
#
# Epoch 01353: val_loss did not improve from -1097.80100
#
# Epoch 01354: val_loss did not improve from -1097.80100
#
# Epoch 01355: val_loss did not improve from -1097.80100
#
# Epoch 01356: val_loss did not improve from -1097.80100
#
# Epoch 01357: val_loss did not improve from -1097.80100
#
# Epoch 01358: val_loss did not improve from -1097.80100
#
# Epoch 01359: val_loss did not improve from -1097.80100
#
# Epoch 01360: val_loss did not improve from -1097.80100
#
# Epoch 01361: val_loss did not improve from -1097.80100
#
# Epoch 01362: val_loss did not improve from -1097.80100
#
# Epoch 01363: val_loss did not improve from -1097.80100
#
# Epoch 01364: val_loss did not improve from -1097.80100
#
# Epoch 01365: val_loss did not improve from -1097.80100
#
# Epoch 01366: val_loss did not improve from -1097.80100
#
# Epoch 01367: val_loss did not improve from -1097.80100
#
# Epoch 01368: val_loss did not improve from -1097.80100
#
# Epoch 01369: val_loss did not improve from -1097.80100
#
# Epoch 01370: val_loss did not improve from -1097.80100
#
# Epoch 01371: val_loss did not improve from -1097.80100
#
# Epoch 01372: val_loss did not improve from -1097.80100
#
# Epoch 01373: val_loss did not improve from -1097.80100
#
# Epoch 01374: val_loss did not improve from -1097.80100
#
# Epoch 01375: val_loss did not improve from -1097.80100
#
# Epoch 01376: val_loss did not improve from -1097.80100
#
# Epoch 01377: val_loss did not improve from -1097.80100
#
# Epoch 01378: val_loss did not improve from -1097.80100
#
# Epoch 01379: val_loss did not improve from -1097.80100
#
# Epoch 01380: val_loss did not improve from -1097.80100
#
# Epoch 01381: val_loss did not improve from -1097.80100
#
# Epoch 01382: val_loss did not improve from -1097.80100
#
# Epoch 01383: val_loss did not improve from -1097.80100
#
# Epoch 01384: val_loss did not improve from -1097.80100
#
# Epoch 01385: val_loss did not improve from -1097.80100
#
# Epoch 01386: val_loss did not improve from -1097.80100
#
# Epoch 01387: val_loss did not improve from -1097.80100
#
# Epoch 01388: val_loss did not improve from -1097.80100
#
# Epoch 01389: val_loss did not improve from -1097.80100
#
# Epoch 01390: val_loss did not improve from -1097.80100
#
# Epoch 01391: val_loss did not improve from -1097.80100
#
# Epoch 01392: val_loss did not improve from -1097.80100
# Epoch 01393: val_loss did not improve from -1097.80100
#
# Epoch 01394: val_loss did not improve from -1097.80100
#
# Epoch 01395: val_loss did not improve from -1097.80100
#
# Epoch 01396: val_loss did not improve from -1097.80100
#
# Epoch 01397: val_loss did not improve from -1097.80100
#
# Epoch 01398: val_loss did not improve from -1097.80100
#
# Epoch 01399: val_loss did not improve from -1097.80100
#
# Epoch 01400: val_loss did not improve from -1097.80100
#
# Epoch 01401: val_loss did not improve from -1097.80100
#
# Epoch 01402: val_loss improved from -1097.80100 to -1102.80720, saving model to MDN/Model3000.hdf5
#
# Epoch 01403: val_loss did not improve from -1102.80720
#
# Epoch 01404: val_loss did not improve from -1102.80720
#
# Epoch 01405: val_loss did not improve from -1102.80720
#
# Epoch 01406: val_loss did not improve from -1102.80720
#
# Epoch 01407: val_loss did not improve from -1102.80720
#
# Epoch 01408: val_loss did not improve from -1102.80720
#
# Epoch 01409: val_loss did not improve from -1102.80720
#
# Epoch 01410: val_loss did not improve from -1102.80720
#
# Epoch 01411: val_loss did not improve from -1102.80720
#
# Epoch 01412: val_loss did not improve from -1102.80720
#
# Epoch 01413: val_loss did not improve from -1102.80720
#
# Epoch 01414: val_loss improved from -1102.80720 to -1105.87285, saving model to MDN/Model3000.hdf5
#
# Epoch 01415: val_loss did not improve from -1105.87285
#
# Epoch 01416: val_loss did not improve from -1105.87285
#
# Epoch 01417: val_loss did not improve from -1105.87285
#
# Epoch 01418: val_loss did not improve from -1105.87285
#
# Epoch 01419: val_loss did not improve from -1105.87285
#
# Epoch 01420: val_loss did not improve from -1105.87285
#
# Epoch 01421: val_loss did not improve from -1105.87285
#
# Epoch 01422: val_loss did not improve from -1105.87285
#
# Epoch 01423: val_loss did not improve from -1105.87285
#
# Epoch 01424: val_loss did not improve from -1105.87285
#
# Epoch 01425: val_loss did not improve from -1105.87285
#
# Epoch 01426: val_loss improved from -1105.87285 to -1118.04090, saving model to MDN/Model3000.hdf5
#
# Epoch 01427: val_loss did not improve from -1118.04090
#
# Epoch 01428: val_loss did not improve from -1118.04090
#
# Epoch 01429: val_loss did not improve from -1118.04090
#
# Epoch 01430: val_loss did not improve from -1118.04090
#
# Epoch 01431: val_loss did not improve from -1118.04090
#
# Epoch 01432: val_loss did not improve from -1118.04090
#
# Epoch 01433: val_loss did not improve from -1118.04090
#
# Epoch 01434: val_loss did not improve from -1118.04090
#
# Epoch 01435: val_loss did not improve from -1118.04090
#
# Epoch 01436: val_loss did not improve from -1118.04090
#
# Epoch 01437: val_loss did not improve from -1118.04090
#
# Epoch 01438: val_loss did not improve from -1118.04090
#
# Epoch 01439: val_loss did not improve from -1118.04090
#
# Epoch 01440: val_loss did not improve from -1118.04090
#
# Epoch 01441: val_loss did not improve from -1118.04090
#
# Epoch 01442: val_loss did not improve from -1118.04090
#
# Epoch 01443: val_loss did not improve from -1118.04090
#
# Epoch 01444: val_loss did not improve from -1118.04090
#
# Epoch 01445: val_loss did not improve from -1118.04090
#
# Epoch 01446: val_loss did not improve from -1118.04090
#
# Epoch 01447: val_loss did not improve from -1118.04090
#
# Epoch 01448: val_loss did not improve from -1118.04090
#
# Epoch 01449: val_loss did not improve from -1118.04090
#
# Epoch 01450: val_loss did not improve from -1118.04090
#
# Epoch 01451: val_loss did not improve from -1118.04090
#
# Epoch 01452: val_loss did not improve from -1118.04090
#
# Epoch 01453: val_loss did not improve from -1118.04090
#
# Epoch 01454: val_loss did not improve from -1118.04090
#
# Epoch 01455: val_loss did not improve from -1118.04090
#
# Epoch 01456: val_loss did not improve from -1118.04090
#
# Epoch 01457: val_loss did not improve from -1118.04090
#
# Epoch 01458: val_loss did not improve from -1118.04090
#
# Epoch 01459: val_loss did not improve from -1118.04090
#
# Epoch 01460: val_loss did not improve from -1118.04090
#
# Epoch 01461: val_loss did not improve from -1118.04090
#
# Epoch 01462: val_loss did not improve from -1118.04090
#
# Epoch 01463: val_loss did not improve from -1118.04090
#
# Epoch 01464: val_loss did not improve from -1118.04090
#
# Epoch 01465: val_loss did not improve from -1118.04090
#
# Epoch 01466: val_loss did not improve from -1118.04090
#
# Epoch 01467: val_loss did not improve from -1118.04090
#
# Epoch 01468: val_loss did not improve from -1118.04090
#
# Epoch 01469: val_loss did not improve from -1118.04090
#
# Epoch 01470: val_loss did not improve from -1118.04090
#
# Epoch 01471: val_loss did not improve from -1118.04090
#
# Epoch 01472: val_loss did not improve from -1118.04090
#
# Epoch 01473: val_loss did not improve from -1118.04090
#
# Epoch 01474: val_loss did not improve from -1118.04090
#
# Epoch 01475: val_loss did not improve from -1118.04090
#
# Epoch 01476: val_loss did not improve from -1118.04090
#
# Epoch 01477: val_loss did not improve from -1118.04090
#
# Epoch 01478: val_loss did not improve from -1118.04090
#
# Epoch 01479: val_loss did not improve from -1118.04090
#
# Epoch 01480: val_loss did not improve from -1118.04090
#
# Epoch 01481: val_loss did not improve from -1118.04090
#
# Epoch 01482: val_loss did not improve from -1118.04090
#
# Epoch 01483: val_loss did not improve from -1118.04090
#
# Epoch 01484: val_loss did not improve from -1118.04090
#
# Epoch 01485: val_loss did not improve from -1118.04090
#
# Epoch 01486: val_loss improved from -1118.04090 to -1124.99354, saving model to MDN/Model3000.hdf5
#
# Epoch 01487: val_loss did not improve from -1124.99354
#
# Epoch 01488: val_loss did not improve from -1124.99354
#
# Epoch 01489: val_loss did not improve from -1124.99354
#
# Epoch 01490: val_loss did not improve from -1124.99354
#
# Epoch 01491: val_loss did not improve from -1124.99354
#
# Epoch 01492: val_loss did not improve from -1124.99354
#
# Epoch 01493: val_loss did not improve from -1124.99354
#
# Epoch 01494: val_loss did not improve from -1124.99354
#
# Epoch 01495: val_loss did not improve from -1124.99354
#
# Epoch 01496: val_loss did not improve from -1124.99354
#
# Epoch 01497: val_loss did not improve from -1124.99354
#
# Epoch 01498: val_loss did not improve from -1124.99354
#
# Epoch 01499: val_loss did not improve from -1124.99354
#
# Epoch 01500: val_loss did not improve from -1124.99354

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
